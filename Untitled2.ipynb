# %% [markdown]
# <a href="https://colab.research.google.com/github/wldud01/Naver_Boost_Study_13th/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 41.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 한글폰트 사용을 위해 설치
# 아래 모듈을 설치하고 불러오면 별도의 한글폰트 설정이 필요 없습니다.
# !pip install koreanize-matplotlib

import koreanize_matplotlib

df = pd.read_csv(
    "https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/online_oversea_sale_202210.csv.zip",
    encoding="cp949")

# %%
print(df.shape)
df.head()
df.describe(include="object")
df["판매유형별"].value_counts()
# Out:
# (2772, 5)
# 면세점 이외    2772
# Name: 판매유형별, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  2772 non-null   object
#  1   상품군별     2772 non-null   object
#  2   판매유형별    2772 non-null   object
#  3   시점       2772 non-null   object
#  4   데이터      2772 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 108.4+ KB

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        시점   데이터
# 0      미국  컴퓨터 및 주변기기  면세점 이외  2017.1/4  1054
# 1      미국  컴퓨터 및 주변기기  면세점 이외  2017.2/4   946
# 2      미국  컴퓨터 및 주변기기  면세점 이외  2017.3/4   791
# 3      미국  컴퓨터 및 주변기기  면세점 이외  2017.4/4   854
# 4      미국  컴퓨터 및 주변기기  면세점 이외  2018.1/4  2033

# %%
# @title 연도와 분기에 대한 파생 변수
df["시점"].value_counts()
# Out:
# 2017.1/4       126
# 2017.2/4       126
# 2022.1/4       126
# 2021.4/4       126
# 2021.3/4       126
# 2021.2/4       126
# 2021.1/4       126
# 2020.4/4       126
# 2020.3/4       126
# 2020.2/4       126
# 2020.1/4       126
# 2019.4/4       126
# 2019.3/4       126
# 2019.2/4       126
# 2019.1/4       126
# 2018.4/4       126
# 2018.3/4       126
# 2018.2/4       126
# 2018.1/4       126
# 2017.4/4       126
# 2017.3/4       126
# 2022.2/4 p)    126
# Name: 시점, dtype: int64

# %% [markdown]
# - 2017~2022년도 데이터

# %%
df["연도"]= df["시점"].str.split(".").str[0].values
df["월"]= df["시점"].str.split(".").str[1].values

day_values = df['월'].str.split('/')
df['월'] = day_values.str[0]
df['일'] = day_values.str[1]
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        시점   데이터    연도  월  일
# 0      미국  컴퓨터 및 주변기기  면세점 이외  2017.1/4  1054  2017  1  4
# 1      미국  컴퓨터 및 주변기기  면세점 이외  2017.2/4   946  2017  2  4
# 2      미국  컴퓨터 및 주변기기  면세점 이외  2017.3/4   791  2017  3  4
# 3      미국  컴퓨터 및 주변기기  면세점 이외  2017.4/4   854  2017  4  4
# 4      미국  컴퓨터 및 주변기기  면세점 이외  2018.1/4  2033  2018  1  4

# %%
df =df.rename(columns={"데이터":"백만"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  2772 non-null   object
#  1   상품군별     2772 non-null   object
#  2   판매유형별    2772 non-null   object
#  3   시점       2772 non-null   object
#  4   백만       2772 non-null   int64
#  5   연도       2772 non-null   object
#  6   월        2772 non-null   object
#  7   일        2772 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 173.4+ KB

# %%
df.loc[df['일']=='4 p)',"일"] =4
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        시점    백만    연도  월  일
# 0      미국  컴퓨터 및 주변기기  면세점 이외  2017.1/4  1054  2017  1  4
# 1      미국  컴퓨터 및 주변기기  면세점 이외  2017.2/4   946  2017  2  4
# 2      미국  컴퓨터 및 주변기기  면세점 이외  2017.3/4   791  2017  3  4
# 3      미국  컴퓨터 및 주변기기  면세점 이외  2017.4/4   854  2017  4  4
# 4      미국  컴퓨터 및 주변기기  면세점 이외  2018.1/4  2033  2018  1  4

# %%
df[["연도","월","일"]]= df[["연도","월","일"]].astype(int)

# %%
# 분기를 월이라고 해버렸네요..^^
df.describe()
# Out:
#                  백만           연도            월       일
# count   2772.000000  2772.000000  2772.000000  2772.0
# mean    1613.116522  2019.272727     2.409091     4.0
# std     4273.426107     1.600909     1.114533     0.0
# min   -10003.000000  2017.000000     1.000000     4.0
# 25%       41.750000  2018.000000     1.000000     4.0
# 50%      291.500000  2019.000000     2.000000     4.0
# 75%     1181.000000  2021.000000     3.000000     4.0
# max    47689.000000  2022.000000     4.000000     4.0

# %% [markdown]
# - 백만 데이터가 편차가 심해보여서 정규화가 필요하지 않을까 싶다..

# %%
#@title 📌 Q2. pivot_table을 사용하여 국가(대륙)별 연도별 판매액의 합계를 분석해 주세요.
from pandas.core.reshape.pivot import pivot_table
df_pivot= pivot_table(data=df , values="백만" ,columns="연도", index="국가(대륙)별",aggfunc="sum")
df_pivot
# Out:
# 연도            2017    2018    2019    2020    2021    2022
# 국가(대륙)별
# 기타           41571   36141   40950   44438   57959   19501
# 대양주          18989   17520   13191   16255   16841    5044
# 미국          142292  156312  186617  255384  277579  103416
# 아세안(ASEAN)   66163   76450   82930  105360   94150   38072
# 유럽연합(EU)     31068   36826   39008   39865   32349    9019
# 일본          125442  178094  189330  220730  280029  131771
# 중국          167240  182068  210418  289446  194380   98572
# 중남미          10245   11669   12981   12563    8298    2629
# 중동            8030    8019    9325   11467    6164    1389

# %%
plt.figure(figsize=(10,12))
df_pivot.plot.barh()
# Out:
# <Axes: ylabel='국가(대륙)별'>

# %%
# 연도에 따른 국가의 판매액 흐름
df_pivot.transpose().plot()
# Out:
# <Axes: xlabel='연도'>

# %% [markdown]
# - 코로나 시기쯤 판매가 급증하다가 갑자기 점점 하락함..
# - 아마도 코로나로 온라인 상품 수요가 증가해서..?
# - 중국 미국 일본이 판매량 많은 국가 top3 인데 신기하게 미국과 일본은 비슷한 추세를 보이는데 중국이 조금 더 일찍 high를 찍고 떨어짐

# %%
#@title 📌 Q3. groupby를 사용하여 2020년의 온라인 해외판매 상품군을 지역별 합계를 구해 분석해 주세요
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        시점    백만    연도  월  일
# 0      미국  컴퓨터 및 주변기기  면세점 이외  2017.1/4  1054  2017  1  4
# 1      미국  컴퓨터 및 주변기기  면세점 이외  2017.2/4   946  2017  2  4
# 2      미국  컴퓨터 및 주변기기  면세점 이외  2017.3/4   791  2017  3  4
# 3      미국  컴퓨터 및 주변기기  면세점 이외  2017.4/4   854  2017  4  4
# 4      미국  컴퓨터 및 주변기기  면세점 이외  2018.1/4  2033  2018  1  4

# %%
df["상품군별"].value_counts()
# Out:
# 컴퓨터 및 주변기기      198
# 가전·전자·통신기기      198
# 소프트웨어           198
# 서 적             198
# 사무·문구           198
# 음반·비디오·악기       198
# 의류 및 패션 관련상품    198
# 스포츠·레저용품        198
# 화장품             198
# 아동·유아용품         198
# 음·식료품           198
# 농축수산물           198
# 생활용품 및 자동차용품    198
# 기 타             198
# Name: 상품군별, dtype: int64

# %%
#@title 2020년도 데이터 추출
df_2020 = df.loc[df["연도"]==2020]
df_2020.head()
# Out:
#    국가(대륙)별        상품군별   판매유형별        시점    백만    연도  월  일
# 12      미국  컴퓨터 및 주변기기  면세점 이외  2020.1/4  1182  2020  1  4
# 13      미국  컴퓨터 및 주변기기  면세점 이외  2020.2/4  1631  2020  2  4
# 14      미국  컴퓨터 및 주변기기  면세점 이외  2020.3/4  1871  2020  3  4
# 15      미국  컴퓨터 및 주변기기  면세점 이외  2020.4/4  1373  2020  4  4
# 34      미국  가전·전자·통신기기  면세점 이외  2020.1/4  1818  2020  1  4

# %%
df_2020_sales = df_2020.groupby(["국가(대륙)별","상품군별"])["백만"].sum().unstack()
df_2020_sales
# Out:
# 상품군별        가전·전자·통신기기    기 타  농축수산물  사무·문구  생활용품 및 자동차용품   서 적  소프트웨어  \
# 국가(대륙)별
# 기타                1716   3345      9    187          1464  4563     21
# 대양주               3825    923      1     21          1198   367     20
# 미국               10103  38731     33    398         11467  9709    865
# 아세안(ASEAN)       12405   2620     17   3279          6432  4192      3
# 유럽연합(EU)          3040   3907      0     25          2560   514     99
# 일본                 404  30509      2   1526          3911  1055     27
# 중국                1353  22736     88    403          7142  6659      4
# 중남미                912    625      0      3          1361   188     15
# 중동                 839    533      0      4          1060   139     17
#
# 상품군별        스포츠·레저용품  아동·유아용품  음·식료품  음반·비디오·악기  의류 및 패션 관련상품  컴퓨터 및 주변기기  \
# 국가(대륙)별
# 기타               755     1646   1596       1410          6501        5653
# 대양주              690      484    403       1800          3746         318
# ...

# %%
df_2020_sales.index
# Out:
# Index(['기타', '대양주', '미국', '아세안(ASEAN)', '유럽연합(EU)', '일본', '중국', '중남미', '중동'], dtype='object', name='국가(대륙)별')

# %%
display(df_2020_sales.loc[["미국","일본","중국","아세안(ASEAN)"]].plot.barh())
display(df_2020_sales.loc[['기타', '대양주','유럽연합(EU)','중남미', '중동']].plot.barh())
# Out:
# <Axes: ylabel='국가(대륙)별'>
# <Axes: ylabel='국가(대륙)별'>

# %%
#@title 📌 Q4. 주요 판매 국가와 상품군에 대해 2021년까지의 연도별 온라인 직접 판매액 합계를 시각화 해주세요
df_max_2021 = df.loc[df["연도"]<2022]

# %%
con_country= (df["국가(대륙)별"]=="미국")|(df["국가(대륙)별"]=="중국")|(df["국가(대륙)별"]=="일본")
con_product = (df["상품군별"]=="의류 및 패션 관련상품")|(df["상품군별"]=="화장품")|(df["상품군별"]=="음반·비디오·악기")

df_max_2021=df_max_2021.loc[con_country&con_product]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(df_max_2021, col="국가(대륙)별", hue="상품군별")
g.map(sns.lineplot, "연도", "백만")
plt.figure(figsize=(12,15))
g.set_axis_labels("연도", "백만")

g.add_legend(title="상품군별")

plt.show()
